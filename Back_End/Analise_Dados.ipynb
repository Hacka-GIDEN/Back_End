# %%
# Bibliotecas para trabalhar com os Dados :
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Chamando o dataset
df = pd.read_csv('convertcsv.csv')
df
# Out:
#            _key     nomes  idade     local  caixa
# 0    cliente_n1    Carlos     19    Manaus     20
# 1    cliente_n2  Vinicius     19  Iranduba    200
# 2    cliente_n3     Souza     19     Maúes    200
# 3    cliente_n4    Carlos     19    Manaus     20
# 4    cliente_n5  Vinicius     19  Iranduba    200
# 5    cliente_n6     Souza     19     Maúes    200
# 6    cliente_n7    Carlos     19    Manaus     20
# 7    cliente_n8  Vinicius     19  Iranduba    200
# 8    cliente_n9     Souza     19     Maúes    200
# 9   cliente_n10    Carlos     19    Manaus     20
# 10  cliente_n11  Vinicius     19  Iranduba    200
# 11  cliente_n12     Souza     19     Maúes    200
# 12  cliente_n13    Carlos     19    Manaus     20
# 13  cliente_n14  Vinicius     19  Iranduba    200
# 14  cliente_n15     Souza     19     Maúes    200
# 15  cliente_n16    Carlos     19    Manaus     20
# 16  cliente_n17  Vinicius     19  Iranduba    200
# 17  cliente_n18     Souza     19     Maúes    200
# 18  cliente_n19    Carlos     19    Manaus     20
# 19  cliente_n20  Vinicius     19  Iranduba    200
# 20  cliente_n21     Souza     19     Maúes    200
# 21  cliente_n22    Carlos     19    Manaus     20
# 22  cliente_n23  Vinicius     19  Iranduba    200
# 23  cliente_n24     Souza     19     Maúes    200
# 24  cliente_n25    Carlos     19    Manaus     20
# 25  cliente_n26  Vinicius     19  Iranduba    200
# 26  cliente_n27     Souza     19     Maúes    200
# 27  cliente_n28    Carlos     19    Manaus     20
# 28  cliente_n29  Vinicius     19  Iranduba    200
# 29  cliente_n30     Souza     19     Maúes    200

# %%
df2 = df.drop(['_key'], axis=1)
df2
# Out:
#        nomes  idade     local  caixa
# 0     Carlos     19    Manaus     20
# 1   Vinicius     19  Iranduba    200
# 2      Souza     19     Maúes    200
# 3     Carlos     19    Manaus     20
# 4   Vinicius     19  Iranduba    200
# 5      Souza     19     Maúes    200
# 6     Carlos     19    Manaus     20
# 7   Vinicius     19  Iranduba    200
# 8      Souza     19     Maúes    200
# 9     Carlos     19    Manaus     20
# 10  Vinicius     19  Iranduba    200
# 11     Souza     19     Maúes    200
# 12    Carlos     19    Manaus     20
# 13  Vinicius     19  Iranduba    200
# 14     Souza     19     Maúes    200
# 15    Carlos     19    Manaus     20
# 16  Vinicius     19  Iranduba    200
# 17     Souza     19     Maúes    200
# 18    Carlos     19    Manaus     20
# 19  Vinicius     19  Iranduba    200
# 20     Souza     19     Maúes    200
# 21    Carlos     19    Manaus     20
# 22  Vinicius     19  Iranduba    200
# 23     Souza     19     Maúes    200
# 24    Carlos     19    Manaus     20
# 25  Vinicius     19  Iranduba    200
# 26     Souza     19     Maúes    200
# 27    Carlos     19    Manaus     20
# 28  Vinicius     19  Iranduba    200
# 29     Souza     19     Maúes    200

# %%
df2.to_csv('convertcsv3.csv')

# %%
df2.describe()
# Out:
#        idade       caixa
# count   30.0   30.000000
# mean    19.0  140.000000
# std      0.0   86.303394
# min     19.0   20.000000
# 25%     19.0   20.000000
# 50%     19.0  200.000000
# 75%     19.0  200.000000
# max     19.0  200.000000

# %% [markdown]
# # Iniciando criação de gráficos:

# %%
sns.set(style='ticks')
df2['caixa'].plot(kind='hist')

# %%
sns.set(style='ticks')
df2['idade'].plot(kind='hist')

# %%
sns.pairplot(df2)

# %% [markdown]
# ## Tentaremos melhorar a qualidade dos gráficos

# %%
#https://matplotlib.org/3.2.1/gallery/lines_bars_and_markers/stem_plot.html#sphx-glr-gallery-lines-bars-and-markers-stem-plot-py

x = df2['<var1>']
y = df2['<var2>']

plt.stem(x, y, use_line_collection=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '<var1>'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-2cf0fd23f4c7> in <module>
#       1 #https://matplotlib.org/3.2.1/gallery/lines_bars_and_markers/stem_plot.html#sphx-glr-gallery-lines-bars-and-markers-stem-plot-py
#       2
# ----> 3 x = df2['<var1>']
#       4 y = df2['<var2>']
#       5
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '<var1>'

# %% [markdown]
# ## Vejamos o que fazer com o Histograma {visto que ele é o + simples e fácil de entender}

# %%
# https://matplotlib.org/3.2.1/gallery/statistics/hist.html#sphx-glr-gallery-statistics-hist-py
# vamos importar +1 biblioteca específica do matplotlib
from matplotlib.ticker import PercentFormatter

# gerando uma distribuição normal, com coord.: (x=0,y=5)
var1 = df2['<var1>']
var2 = df2['<var2>']

# configurações :
fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)
ax.set_ylabel('Amostra')
ax.set_title('Resultado')

# plotando os gráficos :
axs[0].hist(var1)
axs[1].hist(var2)
